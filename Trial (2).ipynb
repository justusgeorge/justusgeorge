# %%
name =  input("Enter your name: ")
if len(name) < 3:
    print("Name must be at least 3 character")
elif len(name) > 10:
    print("Name must be a minimum of 10 character")
else:
    print("Name looks good --o")
# Out:
# Enter your name:  jjjjjjjjjjj
# Name must be a maximum of 10 character

# %%
weight = int(input("Enter your weight: "))
unit = input('(L)bs or (K)g: ')
if unit.lower == "l":
    converted = weight * 0.45
    print(f"You are {converted} pounds ")
else:
    converted = weight / 0.45
    print(f"You are {converted} kilos")
# Out:
# Enter your weight:  55
# (L)bs or (K)g:  k
# You are 122.22222222222221 kilos
